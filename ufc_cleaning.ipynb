# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
ufc=pd.read_csv("UFC DATASETS/UFC.csv")
event_details=pd.read_csv("UFC DATASETS/event_details.csv") 
fight_details=pd.read_csv("UFC DATASETS/fight_details.csv")
fighter_details=pd.read_csv("UFC DATASETS/fighter_details.csv")

# %%
ufc.shape,event_details.shape,fight_details.shape,fighter_details.shape
# Out:
# ((8250, 124), (8250, 6), (8250, 86), (2598, 19))

# %% [markdown]
# ## Initial Data Exploration

# %% [markdown]
# ### UFC

# %%
ufc.head()
# Out:
#            event_id                              event_name        date  \
# 0  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 1  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 2  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 3  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 4  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
#
#            location          fight_id           division  title_fight  \
# 0  Baku, Azerbaijan  36ec204f47e4d613       catch weight            0
# 1  Baku, Azerbaijan  a1afc16e21d1a807        lightweight            0
# 2  Baku, Azerbaijan  7513a00037094075        lightweight            0
# 3  Baku, Azerbaijan  e512b80bbaea36c2       welterweight            0
# 4  Baku, Azerbaijan  03bc32bdb5a33496  light heavyweight            0
#
#                  method  finish_round  match_time_sec  ...  b_splm b_str_acc  \
# ...

# %%
ufc= ufc[["event_id",
"event_name",
"date",
"location",
"fight_id",
"division",
"title_fight",
"method",
"finish_round",
"match_time_sec",
"total_rounds",
]]

# %%
ufc.head()
# Out:
#            event_id                              event_name        date  \
# 0  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 1  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 2  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 3  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 4  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
#
#            location          fight_id           division  title_fight  \
# 0  Baku, Azerbaijan  36ec204f47e4d613       catch weight            0
# 1  Baku, Azerbaijan  a1afc16e21d1a807        lightweight            0
# 2  Baku, Azerbaijan  7513a00037094075        lightweight            0
# 3  Baku, Azerbaijan  e512b80bbaea36c2       welterweight            0
# 4  Baku, Azerbaijan  03bc32bdb5a33496  light heavyweight            0
#
#                  method  finish_round  match_time_sec  total_rounds
# ...

# %%
ufc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   event_id        8250 non-null   object
#  1   event_name      8250 non-null   object
#  2   date            8250 non-null   object
#  3   location        8250 non-null   object
#  4   fight_id        8250 non-null   object
#  5   division        8250 non-null   object
#  6   title_fight     8250 non-null   int64
#  7   method          8250 non-null   object
#  8   finish_round    8250 non-null   int64
#  9   match_time_sec  8250 non-null   int64
#  10  total_rounds    8219 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 709.1+ KB

# %%
ufc.describe(include="all")
# Out:
#                 event_id         event_name        date  \
# count               8250               8250        8250
# unique               738                738         733
# top     a6a9ab5a824e8f66  UFC 2: No Way Out  2016/11/19
# freq                  15                 15          25
# mean                 NaN                NaN         NaN
# std                  NaN                NaN         NaN
# min                  NaN                NaN         NaN
# 25%                  NaN                NaN         NaN
# 50%                  NaN                NaN         NaN
# 75%                  NaN                NaN         NaN
# max                  NaN                NaN         NaN
#
#                       location          fight_id     division  title_fight  \
# count                     8250              8250         8250  8250.000000
# unique                     172              8250          103          NaN
# ...

# %% [markdown]
# ### Event Details

# %%
event_details.head()
# Out:
#            event_id          fight_id           date          location  \
# 0  400c7b43c86d27d3  03bc32bdb5a33496  June 21, 2025  Baku, Azerbaijan
# 1  400c7b43c86d27d3  a1afc16e21d1a807  June 21, 2025  Baku, Azerbaijan
# 2  400c7b43c86d27d3  8e5744c664fec3e9  June 21, 2025  Baku, Azerbaijan
# 3  400c7b43c86d27d3  36ec204f47e4d613  June 21, 2025  Baku, Azerbaijan
# 4  400c7b43c86d27d3  7513a00037094075  June 21, 2025  Baku, Azerbaijan
#
#                 winner         winner_id
# 0  Khalil Rountree Jr.  749f572d1d3161fb
# 1        Rafael Fiziev  c814b4c899793af6
# 2       Curtis Blaydes  fa6796c55d6c5440
# 3     Myktybek Orolbai  bf2c8e01b07d3eb1
# 4       Nazim Sadykhov  ff62013d2fce6d13

# %%
event_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   event_id   8250 non-null   object
#  1   fight_id   8250 non-null   object
#  2   date       8250 non-null   object
#  3   location   8250 non-null   object
#  4   winner     8104 non-null   object
#  5   winner_id  8104 non-null   object
# dtypes: object(6)
# memory usage: 386.8+ KB

# %%
event_details.describe(include="all")
# Out:
#                 event_id          fight_id               date  \
# count               8250              8250               8250
# unique               738              8250                733
# top     a6a9ab5a824e8f66  802c0e4e228996ac  November 19, 2016
# freq                  15                 1                 25
#
#                       location      winner         winner_id
# count                     8250        8104              8104
# unique                     172        1811              1812
# top     Las Vegas, Nevada, USA  Jim Miller  d1941565abf50b16
# freq                      2787          27                27

# %% [markdown]
# ### Fight Details

# %%
fight_details.head()
# Out:
#                                event_name          event_id          fight_id  \
# 0  UFC Fight Night: Hill vs. Rountree Jr.  400c7b43c86d27d3  36ec204f47e4d613
# 1  UFC Fight Night: Hill vs. Rountree Jr.  400c7b43c86d27d3  a1afc16e21d1a807
# 2  UFC Fight Night: Hill vs. Rountree Jr.  400c7b43c86d27d3  7513a00037094075
# 3  UFC Fight Night: Hill vs. Rountree Jr.  400c7b43c86d27d3  e512b80bbaea36c2
# 4  UFC Fight Night: Hill vs. Rountree Jr.  400c7b43c86d27d3  03bc32bdb5a33496
#
#            r_name              r_id               b_name              b_id  \
# 0   Tofiq Musayev  ae81a3ac7b260411     Myktybek Orolbai  bf2c8e01b07d3eb1
# 1   Rafael Fiziev  c814b4c899793af6   Ignacio Bahamondes  e4a47b07044ddd72
# 2  Nazim Sadykhov  ff62013d2fce6d13        Nikolas Motta  37f560436d745c18
# 3    Seokhyeon Ko  4a07b1988477502c         Oban Elliott  6b56e94a59b7b134
# 4    Jamahal Hill  5444c5a201d3ee5a  Khalil Rountree Jr.  749f572d1d3161fb
#
# ...

# %%
fight_details=fight_details[[
    "event_name", "event_id", "fight_id", "r_name", "r_id", 
    "b_name", "b_id", "division", "title_fight", "method", 
    "finish_round", "match_time_sec", "total_rounds"
]]

# %%
fight_details.head()
# Out:
#                                event_name          event_id          fight_id  \
# 0  UFC Fight Night: Hill vs. Rountree Jr.  400c7b43c86d27d3  36ec204f47e4d613
# 1  UFC Fight Night: Hill vs. Rountree Jr.  400c7b43c86d27d3  a1afc16e21d1a807
# 2  UFC Fight Night: Hill vs. Rountree Jr.  400c7b43c86d27d3  7513a00037094075
# 3  UFC Fight Night: Hill vs. Rountree Jr.  400c7b43c86d27d3  e512b80bbaea36c2
# 4  UFC Fight Night: Hill vs. Rountree Jr.  400c7b43c86d27d3  03bc32bdb5a33496
#
#            r_name              r_id               b_name              b_id  \
# 0   Tofiq Musayev  ae81a3ac7b260411     Myktybek Orolbai  bf2c8e01b07d3eb1
# 1   Rafael Fiziev  c814b4c899793af6   Ignacio Bahamondes  e4a47b07044ddd72
# 2  Nazim Sadykhov  ff62013d2fce6d13        Nikolas Motta  37f560436d745c18
# 3    Seokhyeon Ko  4a07b1988477502c         Oban Elliott  6b56e94a59b7b134
# 4    Jamahal Hill  5444c5a201d3ee5a  Khalil Rountree Jr.  749f572d1d3161fb
#
# ...

# %%
fight_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   event_name      8250 non-null   object
#  1   event_id        8250 non-null   object
#  2   fight_id        8250 non-null   object
#  3   r_name          8250 non-null   object
#  4   r_id            8250 non-null   object
#  5   b_name          8250 non-null   object
#  6   b_id            8250 non-null   object
#  7   division        8250 non-null   object
#  8   title_fight     8250 non-null   int64
#  9   method          8250 non-null   object
#  10  finish_round    8250 non-null   int64
#  11  match_time_sec  8250 non-null   int64
#  12  total_rounds    8219 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 838.0+ KB

# %%
fight_details.describe()
# Out:
#        title_fight  finish_round  match_time_sec  total_rounds
# count  8250.000000   8250.000000     8250.000000   8219.000000
# mean      0.055152      2.353576      227.964727      3.135296
# std       0.228290      1.016986       97.419347      0.650322
# min       0.000000      1.000000        5.000000      1.000000
# 25%       0.000000      1.000000      151.000000      3.000000
# 50%       0.000000      3.000000      291.000000      3.000000
# 75%       0.000000      3.000000      300.000000      3.000000
# max       1.000000      5.000000     1080.000000      5.000000

# %% [markdown]
# ### Fighter Details

# %%
fighter_details.head()
# Out:
#                  id            name   nick_name  wins  losses  draws  height  \
# 0  74fefd43f073cd2f       Joe Pardo         NaN     4       6      0  185.42
# 1  8c1ca54b5089d199       Maheshate         NaN    10       4      0  182.88
# 2  4234f0097c83fa62  Sijara Eubanks        SarJ     8       7      0  162.56
# 3  1291edf2d566a71a      Julio Arce         NaN    19       6      0  170.18
# 4  7a47e068f8017019    Val Woodburn  The Animal     7       2      0  172.72
#
#    weight   reach    stance           dob  splm  str_acc  sapm  str_def  \
# 0   95.25     NaN  Southpaw           NaN  0.00        0  0.00        0
# 1   70.31  180.34  Orthodox  Dec 01, 1999  3.86       29  5.64       53
# 2   56.70  170.18  Orthodox  Apr 27, 1985  4.30       43  3.43       57
# 3   65.77  177.80  Southpaw  Oct 27, 1989  4.36       36  3.05       68
# 4   77.11  187.96  Orthodox  Aug 10, 1993  1.60       35  4.93       36
#
#    td_avg  td_avg_acc  td_def  sub_avg
# ...

# %%
fighter_details=fighter_details[[
    "id", 
    "name", 
    "nick_name", 
    "wins", 
    "losses", 
    "draws", 
    "height", 
    "weight", 
    "reach", 
    "stance"
]]

# %%
fighter_details.head()
# Out:
#                  id            name   nick_name  wins  losses  draws  height  \
# 0  74fefd43f073cd2f       Joe Pardo         NaN     4       6      0  185.42
# 1  8c1ca54b5089d199       Maheshate         NaN    10       4      0  182.88
# 2  4234f0097c83fa62  Sijara Eubanks        SarJ     8       7      0  162.56
# 3  1291edf2d566a71a      Julio Arce         NaN    19       6      0  170.18
# 4  7a47e068f8017019    Val Woodburn  The Animal     7       2      0  172.72
#
#    weight   reach    stance
# 0   95.25     NaN  Southpaw
# 1   70.31  180.34  Orthodox
# 2   56.70  170.18  Orthodox
# 3   65.77  177.80  Southpaw
# 4   77.11  187.96  Orthodox

# %%
fighter_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2598 entries, 0 to 2597
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         2598 non-null   object
#  1   name       2598 non-null   object
#  2   nick_name  1682 non-null   object
#  3   wins       2598 non-null   int64
#  4   losses     2598 non-null   int64
#  5   draws      2598 non-null   int64
#  6   height     2577 non-null   float64
#  7   weight     2580 non-null   float64
#  8   reach      1943 non-null   float64
#  9   stance     2521 non-null   object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 203.1+ KB

# %%
fighter_details.describe()
# Out:
#               wins       losses        draws       height       weight  \
# count  2598.000000  2598.000000  2598.000000  2577.000000  2580.000000
# mean     14.499615     6.160123     0.253272   178.279022    76.569217
# std       9.736844     4.534444     0.786718     8.966628    17.926687
# min       0.000000     0.000000     0.000000   152.400000    52.160000
# 25%       9.000000     3.000000     0.000000   172.720000    65.770000
# 50%      13.000000     5.000000     0.000000   177.800000    70.310000
# 75%      18.000000     8.000000     0.000000   185.420000    83.910000
# max     253.000000    53.000000    11.000000   210.820000   349.270000
#
#              reach
# count  1943.000000
# mean    181.991065
# std      10.768292
# min     147.320000
# 25%     175.260000
# 50%     182.880000
# 75%     190.500000
# max     213.360000

# %% [markdown]
# ## Export Cleaned Datasets

# %%
ufc.to_csv("UFC DATASETS/ufc_cleaned.csv",index=False)
event_details.to_csv("UFC DATASETS/event_details_cleaned.csv",index=False)
fight_details.to_csv("UFC DATASETS/fight_details_cleaned.csv",index=False)
fighter_details.to_csv("UFC DATASETS/fighter_details_cleaned.csv",index=False)
